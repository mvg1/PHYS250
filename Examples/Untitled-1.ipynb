# %% [markdown]
# # Ising model cont'd
# ## Starting conversation
#     - Use the slack more often
#     - Comsol package
#         - Multiphysics software???
#         - Electric field modeling, FEM modeling, etc
#         - Basically, there are licenses available throug CSIL or something?
#     - If you use some GitHib thing or software,
#         - DEVELOPMENT OF UNDERSTANDING is of the utmost importance
#         - Do "half an hour, an hour' of research showing you understand what people use the thing for
#
# ## Ising model cont'd
#     - Thank god doesn't look all that complicated
#     - Just kinda a grid of spins that coalless into
#     - General description reminder stuff
#         - 2^n states of the system
#         - Symmetries are degenerate etc
#     - Caluclating statistics
#         - Mean is just Energy of a state *
#         - Variance is the "second moment"
#             - Square of the root mean square... the mean square?
#         - Symmetries
#             - About the best you can get is a factor of 16 by brute force unless you're suuper clever
#             - Instead, we can use monte carlo
#
#     - Monte Carlo
#         - Just take a bunch of random samples
#         - Heat bath method
#             - Always flip a spin according to the Boltzmann factor base on the energy difference
#         - Metropolis
#         - Assumptions for valid monte carlo
#             - Ergodicity:
#                 1. All accessible microstates will be sampled
#                 1. The Markov chain must be able to reach every state of the system
#         - Assumtions
#
#     - I have no idea where "MonteCarloMethods.ipbny" went
